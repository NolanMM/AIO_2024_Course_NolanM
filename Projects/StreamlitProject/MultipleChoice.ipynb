# %% [markdown]
# # Multiple Choice

# %% [markdown]
# ![image.png](attachment:115df5e9-2503-4b34-99e2-1d737ac11242.png)
# ## Question 1: A

# %% [markdown]
# ![image.png](attachment:48cedf9e-637b-4e78-a509-0abf23d77fdd.png)
# ## Question 2: C

# %% [markdown]
# ![image.png](attachment:9e80b589-0b87-4382-ab9a-74b316d8ab61.png)
# ## Question 3: D

# %% [markdown]
# ## Question 4: C

# %% [markdown]
# ![image.png](attachment:8840e1b5-ebe7-4e08-bd5c-b075208c6497.png)
# ## Question 5: A

# %% [markdown]
# ![image.png](attachment:c2e06fae-5e77-4898-a0fd-1aa905becc2d.png)
# ## Question 6: D

# %% [markdown]
# ## Question 7: D

# %% [markdown]
# ![image.png](attachment:f26ceb83-60b1-4924-b8ee-110d0a250627.png)
# ## Question 8: B

# %% [markdown]
# ![image.png](attachment:0f3ec2d9-e363-49be-9112-8bb4b9127eef.png)
# ## Question 9: D

# %% [markdown]
# ![image.png](attachment:88feaaf3-5345-424f-8254-6ae361cdc5b9.png)
# ## Question 10: B
