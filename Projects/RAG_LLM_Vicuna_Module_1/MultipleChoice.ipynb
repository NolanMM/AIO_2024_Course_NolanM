# %% [markdown]
# # Multiple Choice

# %% [markdown]
# ![image.png](attachment:06fe34af-238c-421d-8814-33d7013a0537.png)
# ## Question 1: B
#
# ---

# %% [markdown]
# ![image.png](attachment:1f0cb5a1-cef5-4edc-a071-f3ff8bb806ce.png)
# ## Question 2: A
#
# ---

# %% [markdown]
# ![image.png](attachment:adbb33af-4da5-464e-9631-ef328e82edac.png)
# ## Question 3: D
#
# ---

# %% [markdown]
# ![image.png](attachment:ee4fd9e8-22ad-49f0-8148-2e0980a247db.png)
# ## Question 4: C
#
# ---

# %% [markdown]
# ![image.png](attachment:23baf969-cdf4-4bae-b64c-b9a47cbc9944.png)
# ## Question 5: C
#
# ---

# %% [markdown]
# ![image.png](attachment:49cd8318-2cc3-4964-8e8e-677fab322a96.png)
# ![image.png](attachment:481052ef-7989-4d7e-87dd-a6586f99f3d7.png)
# ## Question 6: A
#
# ---

# %% [markdown]
# ![image.png](attachment:c02c8056-abc5-44fa-b30c-1af18dca7c96.png)
# ## Question 7: C

# %% [markdown]
# ![image.png](attachment:39d1e7c6-1fb9-46f8-89ed-e0a9b42f384a.png)
# ## Question 8: B

# %% [markdown]
# ![image.png](attachment:025f3c49-5970-4424-8710-64b8e68ae00f.png)
# ## Question 9: A

# %% [markdown]
# ![image.png](attachment:20c6c900-8798-452a-9f23-2fd4818b09f8.png)
# ## Question 10: D
