# %% [markdown]
# # Multiple Choice

# %% [markdown]
# ![image.png](attachment:d03b8002-ccc6-4eef-b947-3dc8bcac3518.png)
# ## Question 1: C
#
# ---

# %% [markdown]
# ![image.png](attachment:eb83f7f2-4e0a-49f8-bd3e-7cf8414d2be4.png)
# ## Question 2: C
#
# ---

# %% [markdown]
# ![image.png](attachment:fd8a2828-ec7d-4230-9bf9-f068d854f84a.png)
# ## Question 3: C
#
# ---

# %% [markdown]
# ![image.png](attachment:ce8af5f3-2f25-4f18-b386-bba5d3b5a312.png)
# ## Question 4: A
#
# ---

# %% [markdown]
# ![image.png](attachment:7768560b-9802-487f-81af-07232455e676.png)
# ## Question 5: D
#
# ---

# %% [markdown]
# ![image.png](attachment:6cfecb2d-6b58-445d-9a81-d4ebada533b8.png)
# ![image.png](attachment:cab02fe8-66ce-4b38-88a9-8c4780ccf654.png)
# ## Question 6: D
#
# ---

# %% [markdown]
# ![image.png](attachment:7e9d3901-df13-478f-b377-9286e967c472.png)
# ## Question 7: B

# %% [markdown]
# ![image.png](attachment:21420998-8b21-41de-9b23-9a46d338c81e.png)
# ## Question 8: D

# %% [markdown]
# ![image.png](attachment:ff0e108b-544b-4057-b2d9-e5da35fb9ffc.png)
# ## Question 9: B

# %% [markdown]
# ![image.png](attachment:9978f611-fcdb-40e0-8c40-cd7897c2b57f.png)
# ## Question 10: A
